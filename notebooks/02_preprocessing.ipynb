# %% [markdown]
# import nacessary labiraies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_reg = pd.read_csv('/Users/tameemislam/Documents/Portfolio_project/BMW-sales-data/data/X_Regression.csv')
y_reg = pd.read_csv('/Users/tameemislam/Documents/Portfolio_project/BMW-sales-data/data/y_Regression.csv')

# %%
X_reg.describe()
# Out:
#               Model          Year    Mileage_KM  Engine_Size_L        Hybrid  \
# count  50000.000000  50000.000000  50000.000000   50000.000000  50000.000000
# mean       0.528357      0.501121      0.501539       0.499194      0.254320
# std        0.343042      0.308890      0.289718       0.288308      0.435483
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        0.240857      0.214286      0.250884       0.257143      0.000000
# 50%        0.512521      0.500000      0.501945       0.485714      0.000000
# 75%        0.820424      0.785714      0.753163       0.742857      1.000000
# max        1.000000      1.000000      1.000000       1.000000      1.000000
#
#              Diesel        Petrol      Electric     Automatic        Manual  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.245260      0.251000      0.249420      0.496920      0.503080
# ...

# %%
y_reg.describe()
# Out:
#           Price_USD
# count  50000.000000
# mean       0.500396
# std        0.288876
# min        0.000000
# 25%        0.249281
# 50%        0.500139
# 75%        0.751442
# max        1.000000

# %%
X_reg.isnull().sum()
# Out:
# Model                   0
# Year                    0
# Mileage_KM              0
# Engine_Size_L           0
# Hybrid                  0
# Diesel                  0
# Petrol                  0
# Electric                0
# Automatic               0
# Manual                  0
# Color_Black             0
# Color_White             0
# Color_Blue              0
# Color_Red               0
# Color_Silver            0
# Color_Grey              0
# Region_North America    0
# Region_South America    0
# Region_Europe           0
# Region_Asia             0
# Region_Africa           0
# Region_Middle East      0
# dtype: int64

# %%
y_reg.isnull().sum()
# Out:
# Price_USD    0
# dtype: int64

# %% [markdown]
# # Training of ML model
#
# ### Spliting the data into Training and Testing

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

# %% [markdown]
# - 80% of training data
# - 20% of testing data

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((40000, 22), (40000, 1), (10000, 22), (10000, 1))

# %%
sns.scatterplot(x=y_train['Price_USD'], y=X_train['Year'])
# Out:
# <Axes: xlabel='Price_USD', ylabel='Year'>

# %% [markdown]
# ### Univariate Model

# %%
from sklearn.linear_model import LinearRegression
